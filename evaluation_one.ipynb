# %%
from evaluation.preliminary_evaluation import fa_average_pairwise
from data.data_collection import DataCollector
from visualization.preliminary_fig import visualize_fa

# %%
spambase = DataCollector.collect_data('spambase')
fa_matrix = fa_average_pairwise(spambase, 57, 100, 19)
visualize_fa(fa_matrix)

# %%
breastw = DataCollector.collect_data('breastw')
fa_matrix_breastw = fa_average_pairwise(breastw, 9, 100, 3)
visualize_fa(fa_matrix_breastw)

# %%
btsc = DataCollector.collect_data('btsc')
fa_matrix_btsc = fa_average_pairwise(btsc, 4, 100, 2)
visualize_fa(fa_matrix_btsc)

# %%
spf = DataCollector.collect_data('spf')
fa_matrix_spf = fa_average_pairwise(spf, 24, 100, 8)
visualize_fa(fa_matrix_spf)
