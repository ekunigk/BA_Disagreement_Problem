# %%
from evaluation.preliminary_evaluation import fa_average_pairwise
from data.data_collection import DataCollector
from visualization.preliminary_fig import visualize_fa

# %%
dc = DataCollector()
spambase = dc.collect_data('spambase')
keys = dc.get_keys(spambase, 2)
fa_matrix = fa_average_pairwise(spambase, keys, 100, 19)
visualize_fa(fa_matrix)

# %%
# breastw = dc.collect_data('breastw')
# keys = dc.get_keys(breastw, 1)
# fa_matrix_breastw = fa_average_pairwise(breastw, keys, 9, 100, 3)
# visualize_fa(fa_matrix_breastw)

# %%
# btsc = dc.collect_data('btsc')
# keys = dc.get_keys(btsc, 1)
# fa_matrix_btsc = fa_average_pairwise(btsc, keys, 4, 100, 2)
# visualize_fa(fa_matrix_btsc)

# %%
# spf = dc.collect_data('spf')
# keys = dc.get_keys(spf, 1)
# fa_matrix_spf = fa_average_pairwise(spf, keys, 24, 100, 8)
# visualize_fa(fa_matrix_spf)

# %%
from evaluation.preliminary_evaluation import fa_difference
from visualization.preliminary_fig import visualize_fa_differences

# %%
fa_diff, k_list = fa_difference(spambase, keys, 200, 1, 37, 2)
print(fa_diff.shape)
visualize_fa_differences(fa_diff, k_list)
# Out:
# (18, 10)

# %%
breastw = dc.collect_data('breastw')
keys_breastw1 = dc.get_keys(breastw, 1)
fa_diff_breastw, k_list_breastw = fa_difference(breastw, keys_breastw1, 200, 1, 8, 1)
visualize_fa_differences(fa_diff_breastw, k_list_breastw)

# %%
spf = dc.collect_data('spf')
keys_spf1 = dc.get_keys(spf, 1)
fa_diff_spf, k_list_spf = fa_difference(spf, keys_spf1, 200, 9, 18, 2)
visualize_fa_differences(fa_diff_spf, k_list_spf)
