# %%
from data.data_collector import DataCollector
from data.evaluation_prep import collect_regression_data
from evaluation.structural_regression import pairwise_kfold, multiple_pairwise_kfold

from sklearn.linear_model import LogisticRegression
from visualization.regression_fig import visualize_scores, visualize_scores_all, visualize_attempt

# %%
from evaluation_12 import analyze_explanations

# %%
analyze_explanations('spambase', 200, 19, 1, 15, 0.5, True, False)
# Out:
# tensor([[ 0.0402, -0.0489,  0.0461, -0.7604, -0.3294, -0.0462, -0.5127, -0.0998,
#          -0.0335, -0.1301, -0.3974,  0.1903,  0.0496, -0.1678, -0.2075, -0.2376,
#          -0.2210, -0.1011, -0.0118, -0.8681, -0.0934, -0.1629, -0.4808,  0.0251,
#           0.8110,  0.5609,  1.0000, -0.0150,  0.2595,  0.2701,  0.2915,  0.1988,
#           0.0529,  0.1144,  0.4847, -0.2725,  0.2598, -0.2276,  0.1211,  0.0190,
#           0.5604,  0.5461,  0.5876,  0.4709,  0.4540,  0.9127, -0.0765,  0.2536,
#           0.1480, -0.0858,  0.2915, -0.8474, -0.8563, -0.3409, -0.6582, -0.4441,
#          -0.3424,  0.0000],
#         [ 0.1998,  0.0229,  0.0740,  0.5525,  0.3649,  0.1394,  0.5286,  0.1650,
#           0.2121,  0.0908,  0.1300, -0.0604,  0.0067,  0.0256,  0.2829,  0.3037,
#           0.2527,  0.0121, -0.0061,  0.5884,  0.0254,  0.2883,  0.3302,  0.2618,
#          -0.6830, -0.5166, -1.0000, -0.1879, -0.3266, -0.3787, -0.3944, -0.2208,
# ...

# %%
analyze_explanations('spambase', 200, 19, 2, 15, 0.5, True, False)
# Out:
# tensor([[ 0.0402, -0.0489,  0.0461, -0.7604, -0.3294, -0.0462, -0.5127, -0.0998,
#          -0.0335, -0.1301, -0.3974,  0.1903,  0.0496, -0.1678, -0.2075, -0.2376,
#          -0.2210, -0.1011, -0.0118, -0.8681, -0.0934, -0.1629, -0.4808,  0.0251,
#           0.8110,  0.5609,  1.0000, -0.0150,  0.2595,  0.2701,  0.2915,  0.1988,
#           0.0529,  0.1144,  0.4847, -0.2725,  0.2598, -0.2276,  0.1211,  0.0190,
#           0.5604,  0.5461,  0.5876,  0.4709,  0.4540,  0.9127, -0.0765,  0.2536,
#           0.1480, -0.0858,  0.2915, -0.8474, -0.8563, -0.3409, -0.6582, -0.4441,
#          -0.3424,  0.0000],
#         [ 0.1998,  0.0229,  0.0740,  0.5525,  0.3649,  0.1394,  0.5286,  0.1650,
#           0.2121,  0.0908,  0.1300, -0.0604,  0.0067,  0.0256,  0.2829,  0.3037,
#           0.2527,  0.0121, -0.0061,  0.5884,  0.0254,  0.2883,  0.3302,  0.2618,
#          -0.6830, -0.5166, -1.0000, -0.1879, -0.3266, -0.3787, -0.3944, -0.2208,
# ...

# %%
analyze_explanations('spambase', 200, 19, 3, 15, 0.5, True, False)
# Out:
# tensor([[ 0.0402, -0.0489,  0.0461, -0.7604, -0.3294, -0.0462, -0.5127, -0.0998,
#          -0.0335, -0.1301, -0.3974,  0.1903,  0.0496, -0.1678, -0.2075, -0.2376,
#          -0.2210, -0.1011, -0.0118, -0.8681, -0.0934, -0.1629, -0.4808,  0.0251,
#           0.8110,  0.5609,  1.0000, -0.0150,  0.2595,  0.2701,  0.2915,  0.1988,
#           0.0529,  0.1144,  0.4847, -0.2725,  0.2598, -0.2276,  0.1211,  0.0190,
#           0.5604,  0.5461,  0.5876,  0.4709,  0.4540,  0.9127, -0.0765,  0.2536,
#           0.1480, -0.0858,  0.2915, -0.8474, -0.8563, -0.3409, -0.6582, -0.4441,
#          -0.3424,  0.0000],
#         [ 0.1998,  0.0229,  0.0740,  0.5525,  0.3649,  0.1394,  0.5286,  0.1650,
#           0.2121,  0.0908,  0.1300, -0.0604,  0.0067,  0.0256,  0.2829,  0.3037,
#           0.2527,  0.0121, -0.0061,  0.5884,  0.0254,  0.2883,  0.3302,  0.2618,
#          -0.6830, -0.5166, -1.0000, -0.1879, -0.3266, -0.3787, -0.3944, -0.2208,
# ...

# %%
analyze_explanations('spf', 200, 8, 1, 15, 0.5, True, True, k_mask=8, mask=0)
# Out:
# c:\Users\ellen\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\ellen\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\ellen\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
analyze_explanations('spf', 200, 8, 1, 15, 0.5, True, True, k_mask=6, mask=0)
# Out:
# c:\Users\ellen\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\ellen\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\ellen\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
analyze_explanations('spf', 200, 8, 1, 15, 0.5, True, True, k_mask=16, mask=0)
# Out:
# tensor([[-0.4548,  0.0000,  0.0000, -0.3744,  0.0000,  0.4203,  0.0000, -0.4216,
#          -0.6768,  0.8477, -0.4302,  0.5838,  0.4162,  0.0000, -0.4634,  0.5210,
#          -0.5281,  0.6017, -0.5949, -0.4477, -1.0000,  0.0000,  0.0000,  0.0000,
#           0.0000],
#         [-0.2570,  0.0000, -0.2620,  0.2181, -1.0000, -0.9576, -0.3437, -0.4210,
#           0.9016, -0.4877,  0.0000,  0.4251,  0.3245,  0.2013,  0.0000, -0.4708,
#           0.0000,  0.0000, -0.4079,  0.6261,  0.0000,  0.0000,  0.8051,  0.0000,
#           0.0000],
#         [ 0.0000,  0.0000, -0.5168,  0.3043,  0.1108, -0.5266,  0.1685, -0.1549,
#           0.1482, -0.9279,  0.2079,  0.4383, -0.1584, -0.2800,  0.2267,  0.0000,
#           0.0000, -0.6104,  0.0000,  1.0000,  0.4437,  0.0000,  0.0000,  0.0000,
#           0.0000],
#         [ 0.0000, -0.3122,  0.2644,  0.5025,  0.3570,  0.4801,  0.0000, -0.3827,
#          -0.6967,  0.0000, -0.5188,  1.0000,  0.3417,  0.0000, -0.5024,  0.0000,
# ...

# %%
analyze_explanations('spf', 200, 8, 1, 15, 0.5, True, False, k_mask=8, mask=0)
# Out:
# c:\Users\ellen\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\ellen\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\ellen\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
analyze_explanations('spambase', 200, 19, 1, 15, 0.5, False, False, k_mask=19, mask=0)
# Out:
# c:\Users\ellen\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\ellen\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\ellen\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
analyze_explanations('spambase', 200, 19, 1, 15, 0.5, True, True, k_mask=19, mask=0)
# Out:
# c:\Users\ellen\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\ellen\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\ellen\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
analyze_explanations('spambase', 200, 19, 1, 15, 0.5, True, True, k_mask=5, mask=0)
# Out:
# tensor([[ 0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000, -0.8681,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.9127,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000, -0.8474, -0.8563,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000],
#         [ 0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.5884,  0.0000,  0.0000,  0.0000,  0.0000,
#          -0.6830,  0.0000, -1.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
# ...

# %%
dc = DataCollector()
spf = dc.collect_data('spf')
print(spf['spf_159714_11880_EPOCH-BATCH_ig.pkl'].shape)
model = LogisticRegression(random_state=42, max_iter=100, solver='lbfgs')
scores = pairwise_kfold(dc, spf, 1, 10)
visualize_scores(scores)
# Out:
# torch.Size([389, 24])
# c:\Users\ellen\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\ellen\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\ellen\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
scores = multiple_pairwise_kfold(dc, spf, 1)
visualize_attempt(scores)

# %%
scores1 = pairwise_kfold(dc, spf, 1, 10)
spambase = dc.collect_data('spambase')
scores2 = pairwise_kfold(dc, spambase, 1, 10)
breastw = dc.collect_data('breastw')
scores3 = pairwise_kfold(dc, breastw, 1, 10)
btsc = dc.collect_data('btsc')
scores4 = pairwise_kfold(dc, btsc, 1, 10)

scores_all = {0: scores1, 1: scores2, 2: scores3, 3: scores4}
visualize_attempt(scores_all, ('spf', 'spambase', 'breastw', 'btsc'))

# %%
# dc = DataCollector()
# breastw = dc.collect_data('breastw')
# model = LogisticRegression(random_state=42, max_iter=100)
# scores = pairwise_kfold(dc, breastw, 1, 10)
# visualize_scores(scores)

# %%
from data.evaluation_prep import prepare_umap_data
from evaluation.umap import visualize_umap, visualize_umap_nolegend, project_umap, visualize_umap2

# %%
spambase = dc.collect_data('spambase')
keys = dc.get_keys(spambase)
umap_data = prepare_umap_data(spambase, keys)

# %%
# for i in (0.0, 0.1, 0.25, 0.5, 0.99):
#     embedding = project_umap(umap_data, n_neighbors=15, min_dist=i)
#     visualize_umap(umap_data, embedding)

# %%
from evaluation_12 import analyze_explanations

# %%
analyze_explanations('spambase', model_number=1, n_fa=200, k_fa=19, n_neighbors=15, min_dist=0.5)
# Out:
# 921
# c:\Users\ellen\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\ellen\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\ellen\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
analyze_explanations('spambase', model_number=2, n_fa=200, k_fa=19, n_neighbors=15, min_dist=0.5)

# %%
analyze_explanations('spambase', 1, 200, 19, 15, 0.5)
# Out:
# 921
# c:\Users\ellen\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\ellen\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\ellen\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
analyze_explanations('spf', 1, 200, 8, 15, 0.5)
# Out:
# 389
# c:\Users\ellen\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\ellen\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\ellen\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
analyze_explanations('btsc', 1, 100, 2, 15, 0.5)
# Out:
# 150
# c:\Users\ellen\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\ellen\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\ellen\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
analyze_explanations('breastw', 1, 200, 3, 15, 0.5)
# Out:
# 1000
# c:\Users\ellen\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\ellen\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\ellen\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
