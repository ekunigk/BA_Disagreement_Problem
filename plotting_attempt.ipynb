# %%
from data_management.data_collector import DataCollector
from evaluation3 import evaluate_autoencoder

from data_management.data_saving import save_dict, load_dict
from visualization.translator_fig import visualize_multiple_scores, show_rankings_bp, show_three_bp, show_three

# %%
import pandas as pd

# %%
# ae166_m2 = evaluate_autoencoder('breastw', 2, [9, 16, 6], [6, 16, 9], 20, 0.01, 16, True)

# %%
kfold_dict = load_dict('saves/bw/kfold/ae16-6-16_m1_20_01_16')
df = pd.DataFrame(kfold_dict)
show_three(df)

# %%
kfold_dict = load_dict('saves/bw/kfold/ae16-6-16_m2_20_01_16')
df = pd.DataFrame(kfold_dict)
show_three_bp(df)

# %%
kfold_dict['autoencoder mse']['KS_IG']
# Out:
# [0.21143584,
#  0.1445469,
#  0.11537605,
#  0.0451826,
#  0.060943168,
#  0.091405585,
#  0.07033795,
#  0.08606926,
#  0.077443205,
#  0.042101484]

# %%
score_dict, kfold_dict = ae166_m2

# %%
save_dict(score_dict, 'saves/bw/scores/ae16-6-16_m2_20_01_16')
save_dict(kfold_dict, 'saves/bw/kfold/ae16-6-16_m2_20_01_16')

# %%
# score_dict, kfold_dict = ae166_m1
# show_rankings_bp(kfold_dict['autoencoder mse'], (''))
